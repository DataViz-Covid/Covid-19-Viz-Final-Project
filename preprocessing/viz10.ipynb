# %%
import pandas as pd

# %%
df= pd.read_csv('../data/owid-covid-data.csv')
df.tail()
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 250846      ZMB    Africa    Zambia  31/03/2020         35.0        0.0
# 250847      ZMB    Africa    Zambia  01/04/2020         36.0        1.0
# 250848      ZWE    Africa  Zimbabwe  20/03/2020          1.0        1.0
# 250849      ZWE    Africa  Zimbabwe  21/03/2020          3.0        2.0
# 250850      ZWE    Africa  Zimbabwe  22/03/2020          3.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 250846               4.571           NaN         NaN                  NaN
# 250847               3.429           NaN         NaN                  NaN
# 250848                 NaN           NaN         NaN                  NaN
# 250849                 NaN           NaN         NaN                  NaN
# 250850                 NaN           NaN         NaN                  NaN
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df_new = pd.DataFrame(columns=["continent", "location", "weekly_hosp_admissions_per_million", "median_age", "aged_65_older", "aged_70_older", "life_expectancy"])
df_new= df.groupby(['continent', 'location'])['weekly_hosp_admissions_per_million', 'median_age', "aged_65_older", "aged_70_older", "life_expectancy"].max().reset_index()
df_new
# Out:
# C:\Users\clara\AppData\Local\Temp\ipykernel_21800\607435987.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_new= df.groupby(['continent', 'location'])['weekly_hosp_admissions_per_million', 'median_age'].max().reset_index()
#          continent      location  weekly_hosp_admissions_per_million  \
# 0           Africa       Algeria                                 NaN
# 1           Africa        Angola                                 NaN
# 2           Africa         Benin                                 NaN
# 3           Africa      Botswana                                 NaN
# 4           Africa  Burkina Faso                                 NaN
# ..             ...           ...                                 ...
# 230  South America      Paraguay                                 NaN
# 231  South America          Peru                                 NaN
# ...

# %%
df_new=df_new.dropna()
df_new
# Out:
#          continent        location  weekly_hosp_admissions_per_million  \
# 46          Africa    South Africa                             303.604
# 71            Asia          Israel                             393.057
# 80            Asia        Malaysia                             488.004
# 93            Asia       Singapore                              51.800
# 94            Asia     South Korea                             260.461
# 111         Europe         Belgium                             428.194
# 113         Europe        Bulgaria                           10536.325
# 114         Europe         Croatia                             578.244
# 116         Europe         Czechia                             703.736
# 117         Europe         Denmark                             494.708
# 119         Europe         Estonia                             468.397
# 122         Europe          France                             369.324
# ...

# %%
df_new.to_csv("../data_clean/viz10.csv")
