# %%
import pandas as pd

# %%
df= pd.read_csv('../data/owid-covid-data.csv')
df.tail()
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 250846      ZMB    Africa    Zambia  31/03/2020         35.0        0.0
# 250847      ZMB    Africa    Zambia  01/04/2020         36.0        1.0
# 250848      ZWE    Africa  Zimbabwe  20/03/2020          1.0        1.0
# 250849      ZWE    Africa  Zimbabwe  21/03/2020          3.0        2.0
# 250850      ZWE    Africa  Zimbabwe  22/03/2020          3.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 250846               4.571           NaN         NaN                  NaN
# 250847               3.429           NaN         NaN                  NaN
# 250848                 NaN           NaN         NaN                  NaN
# 250849                 NaN           NaN         NaN                  NaN
# 250850                 NaN           NaN         NaN                  NaN
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df_new = pd.DataFrame(columns=["continent", "location", "total_cases", "population_density"])
df_new= df.groupby(['continent', 'location'])['total_cases', 'population_density', 'total_deaths_per_million'].max().reset_index()
df_new
# Out:
# C:\Users\clara\AppData\Local\Temp\ipykernel_18348\216430804.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_new= df.groupby(['continent', 'location'])['total_cases', 'population_density', 'total_deaths_per_million'].max().reset_index()
#          continent      location  total_cases  population_density  \
# 0           Africa       Algeria     271292.0              17.348
# 1           Africa        Angola     105095.0              23.890
# 2           Africa         Benin      27989.0              99.110
# 3           Africa      Botswana     328760.0               4.044
# 4           Africa  Burkina Faso      22025.0              70.151
# ..             ...           ...          ...                 ...
# 230  South America      Paraguay     800163.0              17.144
# 231  South America          Peru    4475610.0              25.129
# ...

# %%
df_new=df_new.dropna()

# %%
df_new
# Out:
#          continent      location  total_cases  population_density  \
# 0           Africa       Algeria     271292.0              17.348
# 1           Africa        Angola     105095.0              23.890
# 2           Africa         Benin      27989.0              99.110
# 3           Africa      Botswana     328760.0               4.044
# 4           Africa  Burkina Faso      22025.0              70.151
# ..             ...           ...          ...                 ...
# 230  South America      Paraguay     800163.0              17.144
# 231  South America          Peru    4475610.0              25.129
# 232  South America      Suriname      82020.0               3.612
# 233  South America       Uruguay    1029564.0              19.751
# 234  South America     Venezuela     551024.0              36.253
#
#      total_deaths_per_million
# 0                     153.241
# 1                      54.230
# 2                      12.207
# 3                    1093.411
# ...

# %%
df_new=df_new.replace('United States','United States of America')
df_new=df_new.replace('Democratic Republic of Congo','Democratic Republic of the Congo')
df_new=df_new.replace('Congo','Republic of Congo')
df_new=df_new.replace("Cote d'Ivoire",'Ivory Coast')
df_new=df_new.replace("Guinea-Bissau",'Guinea Bissau')
df_new=df_new.replace("Tanzania",'United Republic of Tanzania')
df_new=df_new.replace("Eswatini",'Swaziland')
df_new=df_new.replace("Serbia",'Republic of Serbia')
df_new=df_new.replace("North Macedonia",'Macedonia')
df_new=df_new.replace("Czechia",'Czech Republic')

# %%
df_new.to_csv("../data_clean/viz1.csv")
